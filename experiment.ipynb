# %% [markdown]
# ## This notebook is to experiment with concepts shown in Machine Learning Course - Coursera

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.random.normal(size = 30)
y = np.random.normal(size = 30)

plt.scatter(x,y)

# %%
x = [abs(i) for i in x]
y = [abs(i) for i in y]

plt.scatter(x,y)

# %%
diff = max(x) - min(x)
mean_number = np.mean(x)

x = [abs((i - mean_number)/(diff)) for i in x]

diff = max(y) - min(y)
mean_number = np.mean(y)

y = [abs((i - mean_number)/(diff)) for i in y]

plt.scatter(x,y)
